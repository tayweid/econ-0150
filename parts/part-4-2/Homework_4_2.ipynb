# %% [markdown]
# # ECON 0150 | Spring 2026 | Homework 4.2

# %% [markdown]
# ### Due: Sunday March 29, at 11:59PM
#
# Homework is designed to both test your knowledge and challenge you to apply familiar concepts in new applications. Answer clearly and completely. You are welcomed and encouraged to work in groups so long as your work is your own. Use the provided datasets to answer the following questions. Then submit your figures and answers to Gradescope.

# %%
# Imports
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# File Path
file_path = 'https://tayweid.github.io/econ-0150/data/'

# %% [markdown]
# ## Q1. Mental Health and Income Group
#
# The 2011 Behavioral Risk Factor Surveillance System (BRFSS) contains individual-level data with the following variables:
#
# - `MENTHLTH` – days of Poor Mental Health in the Past 30 Days
# - `INCOME2` – income category (1 = less than \$10,000, ..., 8 = \$75,000 or more)
#
# Create a binary variable `under_10k` equal to 1 if `INCOME2 == 1` and 0 otherwise. Run a linear regression such that the mental health variable is the outcome variable and `under_10k` is the independent variable.

# %%
data = pd.read_csv(file_path + 'BRFSS_cleaned.csv')
# Create a binary categorical variable for those making less than 10k
data['under_10k'] = (data['INCOME2'] == 1).astype(int)
data
# Out:
#         GEOID   AGE  INCOME2  MENTHLTH                county_name  \
# 0        1073  48.0      8.0       0.0  Jefferson County, Alabama
# 1        1073  34.0      7.0       0.0  Jefferson County, Alabama
# 2        1073  75.0      6.0       0.0  Jefferson County, Alabama
# 3        1073  60.0      4.0       5.0  Jefferson County, Alabama
# 4        1073  78.0      1.0       0.0  Jefferson County, Alabama
# ...       ...   ...      ...       ...                        ...
# 243397  56025  22.0      6.0       3.0    Natrona County, Wyoming
# 243398  56025  39.0      7.0       0.0    Natrona County, Wyoming
# 243399  56025  28.0      7.0       0.0    Natrona County, Wyoming
# 243400  56025  47.0      NaN       0.0    Natrona County, Wyoming
# 243401  56025  25.0      1.0      22.0    Natrona County, Wyoming
#
#         unemployment_rate  Year  College  Married  Female   BMI5  under_10k
# 0                     9.3  2011        1      1.0       1  23.40          0
# 1                     9.3  2011        1      0.0       0  30.13          0
# 2                     9.3  2011        0      1.0       1  29.18          0
# 3                     9.3  2011        1      1.0       0  32.02          0
# 4                     9.3  2011        0      0.0       1  24.02          1
# ...                   ...   ...      ...      ...     ...    ...        ...
# 243397                5.1  2011        1      0.0       1  24.28          0
# 243398                5.1  2011        0      1.0       1  22.05          0
# 243399                5.1  2011        1      1.0       1  27.46          0
# 243400                5.1  2011        0      0.0       1  25.84          0
# 243401                5.1  2011        1      0.0       0    NaN          1
#
# [243402 rows x 12 columns]

# %%
sns.stripplot(data.sample(1000), x = 'under_10k', y = 'MENTHLTH')
# Out:
# <Axes: xlabel='under_10k', ylabel='MENTHLTH'>

# %%
# Step 1. write out a model
# MENTHLTH ~ b_0 + b_1 * under_10k

# Step 2. run a model

# %% [markdown]
# a) What does $\hat\beta_0$ represent in context?

# %% [markdown]
# b) What does $\hat\beta_1$ represent in context?

# %% [markdown]
# ## Q2. Reading Regression Output
#
# A researcher wants to test whether having a college degree is associated with higher hourly wages. They code a binary variable `college` equal to 1 if the worker has a college degree and 0 otherwise, then estimate the following model:
#
# $$\texttt{wage}_i = \beta_0 + \beta_1 \cdot \texttt{college}_i + \varepsilon_i$$
#
# Their regression output shows:
#
# ```
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       18.42      0.310     59.419      0.000      17.81      19.03
# college          9.65      0.440     21.932      0.000       8.79      10.51
# ------------------------------------------------------------------------------
# ```

# %% [markdown]
# a) Interpret the intercept coefficient (18.42) in context.

# %% [markdown]
# b) Interpret the slope coefficient (9.65) in context.

# %% [markdown]
# c) What is the null hypothesis being tested for the `college` coefficient?

# %% [markdown]
# d) Interpret the p-value in words.
